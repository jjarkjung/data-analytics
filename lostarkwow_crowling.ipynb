# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import time
import sys
import re
import math
import numpy 
import pandas as pd   
import xlwt 
import random
import os
import urllib.request
import urllib

chrome_path = 'C:\\py_temp\\chromedriver_win32\\chromedriver.exe'
driver = webdriver.Chrome(chrome_path)
driver.maximize_window()
url = 'https://loawa.com/main'
driver.get(url)

driver.delete_all_cookies()
time.sleep(2)

job = input(''' 
 1.워로드               2.디스트로이어       3.버서커          4.홀리나이트
 5.인파이터             6.배틀마스터         7.기공사          8.창술사
 9.스트라이커          10.데빌헌터         11.블래스터       12.호크아이
13.스카우터            14.건슬링어         15.서머너         16.바드
17.아르카나            18.소서리스         19.블레이드       20.데모닉
21.리퍼

1.위 분야 중에서 자료를 수집할 직업의 번호를  선택하세요: ''')



cnt = int(input('2.크롤링 할 건수는 몇건입니까?: '))
page_cnt = math.ceil(cnt/60)
import time
time.sleep(3.5)

search = driver.find_element_by_xpath('/html/body/div[3]/div/div/ul/li[4]/a')

search.click()



f_dir = input('3.파일을 저장할 폴더명만 쓰세요(엔터키 입력시 :c:\\temp\\ 아래에 저장됨):')
if f_dir=='' :
    f_dir="c:\\temp\\"

print("\n")

if job == '1' :
    job_name='워로드'
elif job =='2' :
    job_name='디스트로이어'
elif job =='3' :
    job_name='버서커'
elif job =='4' :
    job_name='홀리나이트'
elif job =='5' :
    job_name='인파이터'
elif job =='6' :
    job_name='배틀마스터'
elif job =='7' :
    job_name='기공사'
elif job =='8' :
    job_name='창술사'
elif job =='9' :
    job_name='스트라이커'
elif job =='10' :
    job_name='데빌헌터'
elif job =='11' :
    job_name='블래스터'
elif job =='12' :
    job_name='호크아이'
elif job =='13' :
    job_name='스카우터'
elif job =='14' :
    job_name='건슬링어'
elif job =='15' :
    job_name='서머너'
elif job =='16' :
    job_name='바드'
elif job =='17' :
    job_name='아르카나'
elif job =='18' :
    job_name='소서리스'
elif job =='19' :
    job_name='블레이드'
elif job =='20' :
    job_name='데모닉'
elif job =='21' :
    job_name='리퍼'

#저장된 파일위치와 이름 지정
now = time.localtime()
s = '%04d-%02d-%02d-%02d-%02d-%02d' % (now.tm_year, now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min, now.tm_sec)

query_txt='로아와'
query_url='https://loawa.com/main'

os.makedirs(f_dir+s+'-'+query_txt+'-'+job_name)
os.chdir(f_dir+s+'-'+query_txt+'-'+job_name)

ff_dir=f_dir+s+'-'+query_txt+'-'+job_name
ff_name=f_dir+s+'-'+query_txt+'-'+job_name+'\\'+s+'-'+query_txt+'-'+job_name+'.txt'
fc_name=f_dir+s+'-'+query_txt+'-'+job_name+'\\'+s+'-'+query_txt+'-'+job_name+'.csv'
fx_name=f_dir+s+'-'+query_txt+'-'+job_name+'\\'+s+'-'+query_txt+'-'+job_name+'.xls'

img_dir = ff_dir+"\\images"
os.makedirs(img_dir)
os.chdir(img_dir)

s_time = time.time( )

chrome_path = 'C:\\py_temp\\chromedriver_win32\\chromedriver.exe'
driver = webdriver.Chrome(chrome_path)



driver.get(query_url)
time.sleep(3)

driver.delete_all_cookies()
time.sleep(2)

#분야별 활성화 버튼을 눌러 페이지를 엽니다

if job == '1' :   # 워로드
    driver.find_element_by_xpath("""//*[@id="pills-item"]/div[1]/table/tbody/tr/td[1]/table/tbody/tr[4]/td[2]/label""").click( )
elif job == '2' :  #디스트로이어
    driver.find_element_by_xpath("""//*[@id="pills-item"]/div[1]/table/tbody/tr/td[1]/table/tbody/tr[4]/td[3]/label""").click( )
elif job == '3' :   #버서커
    driver.find_element_by_xpath("""//*[@id="pills-item"]/div[1]/table/tbody/tr/td[1]/table/tbody/tr[4]/td[4]/label""").click( )
elif job == '4' :    #홀리나이트
    driver.find_element_by_xpath("""//*[@id="pills-item"]/div[1]/table/tbody/tr/td[1]/table/tbody/tr[4]/td[5]/label""").click( )
elif job == '5' :    #인파
    driver.find_element_by_xpath("""//*[@id="pills-item"]/div[1]/table/tbody/tr/td[1]/table/tbody/tr[6]/td[2]/label""").click( )
elif job == '6' :    #배틀마스터
    driver.find_element_by_xpath("""//*[@id="pills-item"]/div[1]/table/tbody/tr/td[1]/table/tbody/tr[6]/td[3]/label""").click( )
elif job == '7' :    #기공사
    driver.find_element_by_xpath("""//*[@id="pills-item"]/div[1]/table/tbody/tr/td[1]/table/tbody/tr[6]/td[4]/label""").click( )
elif job == '8' :    #창술사
    driver.find_element_by_xpath("""//*[@id="pills-item"]/div[1]/table/tbody/tr/td[1]/table/tbody/tr[6]/td[5]/label""").click( )
elif job == '9' :    #스트라이커
    driver.find_element_by_xpath("""//*[@id="pills-item"]/div[1]/table/tbody/tr/td[1]/table/tbody/tr[7]/td[1]/label""").click( )
elif job == '10' :   #데빌헌터
    driver.find_element_by_xpath("""//*[@id="pills-item"]/div[1]/table/tbody/tr/td[1]/table/tbody/tr[9]/td[2]/label""").click( )
elif job == '11' :   #블래스터
    driver.find_element_by_xpath("""//*[@id="pills-item"]/div[1]/table/tbody/tr/td[1]/table/tbody/tr[9]/td[3]/label""").click( )
elif job == '12' :   #호크아이
    driver.find_element_by_xpath("""//*[@id="pills-item"]/div[1]/table/tbody/tr/td[1]/table/tbody/tr[9]/td[4]/label""").click( )
elif job == '13' :   #스카우터
    driver.find_element_by_xpath("""//*[@id="pills-item"]/div[1]/table/tbody/tr/td[1]/table/tbody/tr[9]/td[5]/label""").click( )
elif job == '14' :  #건슬링어
    driver.find_element_by_xpath("""//*[@id="pills-item"]/div[1]/table/tbody/tr/td[1]/table/tbody/tr[10]/td[1]/label""").click( )
elif job == '15' :   #서머너
    driver.find_element_by_xpath("""//*[@id="pills-item"]/div[1]/table/tbody/tr/td[1]/table/tbody/tr[12]/td[2]/label""").click( )
elif job == '16' :   #바드
    driver.find_element_by_xpath("""//*[@id="pills-item"]/div[1]/table/tbody/tr/td[1]/table/tbody/tr[12]/td[3]/label""").click( )
elif job == '17' :   #아르카나
    driver.find_element_by_xpath("""//*[@id="pills-item"]/div[1]/table/tbody/tr/td[1]/table/tbody/tr[12]/td[4]/label""").click( )
elif job == '18' :   #소서리스
    driver.find_element_by_xpath("""//*[@id="pills-item"]/div[1]/table/tbody/tr/td[1]/table/tbody/tr[12]/td[5]/label""").click( )
elif job == '19' :   #블레이드
    driver.find_element_by_xpath("""//*[@id="pills-item"]/div[1]/table/tbody/tr/td[1]/table/tbody/tr[14]/td[2]/label""").click( )
elif job == '20' :   #데모닉
    driver.find_element_by_xpath("""//*[@id="pills-item"]/div[1]/table/tbody/tr/td[1]/table/tbody/tr[14]/td[3]/label""").click( )
elif job == '21' :   #리퍼
    driver.find_element_by_xpath("""//*[@id="pills-item"]/div[1]/table/tbody/tr/td[1]/table/tbody/tr[14]/td[4]/label""").click( )

    
#Step 5. 화면을 스크롤해서 아래로 이동합니다

def scroll_down(driver):
    driver.execute_script("window.scrollTo(0,document.body.scrollHeight);")
    time.sleep(1)

scroll_down(driver)

import pyautogui
pyautogui.scroll(3000)

ranking2=[]
title2=[]
o_price2=[]
p_price2=[]
discount2 = []
rocket2=[]
soldout2=[]
score2=[]
sat_count2=[]

count = 1
file_no = 1

for x in range(1,page_cnt + 1) :
    
    pyautogui.scroll(3000)
    
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')

    #이미지 추출하기
    img_src2=[]   # 이미지 URL 저장변수
    
    item_result = soup.find('ul','baby-product-list')
    item_result2 = item_result.find_all('li')

    for li in item_result2:

            if count > cnt :
                break

            try :
                photo = li.find('dt','image').find('img')['src']
            except AttributeError :
                continue
                
            full_photo = 'https:' + photo
            urllib.request.urlretrieve(full_photo,str(file_no)+'.jpg')
            time.sleep(0.5)

            if  file_no > cnt :
                break

            f = open(ff_name, 'a',encoding='UTF-8')
            f.write("-----------------------------------------------------"+"\n")
            print("-" *70)
            
            ranking = count
            print("1.판매순위:",ranking)
            f.write('1.판매순위:'+ str(ranking) + "\n")

            try :
                t = li.find('div',class_='name').get_text().replace("\n","")
            except  :
                title = '제품소개가 없습니다'
                print(title.replace("\n",""))
                f.write('2.제품소개:'+ title + "\n")
            else :
                title = t.replace("\n","").strip()
                print("2.제품소개:", title.replace("\n","").strip())                  
                f.write('2.제품소개:'+ title + "\n")

            try :
                p_price = li.find('strong','price-value').get_text().replace("\n","")
            except  :
                p_price = '0'
                print("3.판매가격:", p_price.replace("\n",""))
                f.write('3.판매가격:'+ p_price + "\n")
            else :
                print("3.판매가격:", p_price.replace("\n",""))
                f.write('3.판매가격:'+ p_price + "\n")

            try :
                o_price = li.find('del','base-price').get_text().replace("\n","")
            except  :
                o_price = p_price
                print("4.원래가격:",o_price.replace("\n",""))
                f.write('4.원래가격:'+ o_price + "\n")
            else :
                print("4.원래가격:",o_price.replace("\n",""))
                f.write('4.원래가격:'+ o_price + "\n")

            try :
                discount = li.find('span','discount-percentage').get_text().replace("\n","")
            except  :
                discount = '0'
                print("5:할인률:", discount)
                f.write('5.할인율:'+ discount + "\n")
            else :
                print("5:할인률:", discount)
                f.write('5.할인율:'+ discount + "\n")

            try :
                rocket = li.find('span','badge rocket').find('img')['alt']
            except  :
                rocket = ''
                print("6:로켓배송여부:", rocket)
                f.write('6:로켓배송여부:'+ rocket + "\n")
            else :
                print("6:로켓배송여부:", rocket)
                f.write('6:로켓배송여부:'+ rocket + "\n")

            try :
                soldout = li.find('div','out-of-stock').get_text().replace("\n","").strip()
            except :
                soldout = ''
                print("7:품절여부:", soldout)
                f.write('7.품절여부:'+ soldout + "\n")
            else :
                print("7:품절여부:", soldout)
                f.write('7.품절여부:'+ soldout + "\n")

            try :
                sat_count = li.find('span','rating-total-count').get_text().replace("(","").replace(")","")
            except  :
                sat_count='0'
                print('8.상품평수: ',sat_count)
                f.write('8.상품평수:'+ sat_count + "\n")
            else :
                print('8.상품평수:',sat_count)
                f.write('8.상품평수:'+ sat_count + "\n")

            try :
                score= li.find('em','rating').get_text()
            except  :
                score='0'
                print('9.평점: 5.0 /',score)
                f.write('9.평점: 5.0 /'+ score + "\n")
            else :     
                print('9.평점: 5.0 /',score)
                f.write('9.평점: 5.0 /'+ score + "\n")

            print("-" *70)

            f.close( )

            time.sleep(0.6)

            ranking2.append(ranking)
            title2.append(title.replace("\n",""))
            o_price2.append(o_price.replace("\n",""))
            p_price2.append(p_price.replace("\n",""))
            rocket2.append(rocket.replace("\n",""))
            soldout2.append(soldout)
            discount2.append(discount)
            score2.append(score)

            try :   
                sat_count2.append(sat_count)
            except IndexError :
                sat_count2.append(0)
                
            count += 1
            file_no += 1
            
    x += 1     
    
    #driver.delete_all_cookies()
    time.sleep(2)
    
    try :
        driver.find_element_by_link_text('%s' %x).click() # 다음 페이지번호 클릭
    except :
        pass
# Out:
# C:\Users\10956\AppData\Local\Temp/ipykernel_2992/2750572409.py:16: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chrome_path)
#
#  1.워로드               2.디스트로이어       3.버서커          4.홀리나이트
#  5.인파이터             6.배틀마스터         7.기공사          8.창술사
#  9.스트라이커          10.데빌헌터         11.블래스터       12.호크아이
# 13.스카우터            14.건슬링어         15.서머너         16.바드
# 17.아르카나            18.소서리스         19.블레이드       20.데모닉
# 21.리퍼
#
# 1.위 분야 중에서 자료를 수집할 직업의 번호를  선택하세요: 6
# 2.크롤링 할 건수는 몇건입니까?: 20
# C:\Users\10956\AppData\Local\Temp/ipykernel_2992/2750572409.py:41: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search = driver.find_element_by_xpath('/html/body/div[3]/div/div/ul/li[4]/a')
# 3.파일을 저장할 폴더명만 쓰세요(엔터키 입력시 :c:\temp\ 아래에 저장됨):
# ...

# %%
#20개 크롤 링 후 더보기 누르기 하기
#해결해야 할것 21번에 광고 스킵하고 크롤링 하기
